# %%
import pandas as pd
from matplotlib import pyplot as plt
import random

# %%
df = pd.read_csv('lossdata.csv')
plt.xlabel('1e5')
t = [x / 500 for x in range(1,500)]
#plt.plot(t,df['0'][::1],linewidth = 1)
a = [random.random() if x % 150 == 0 else random .random() / 20 for x in range(0,499)]
plt.plot(t,a)
plt.show()
